# %% [markdown]
# # Prompt2PromoLab
#
# Visão geral do repositório, fluxo de geração e arquivos disponíveis.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

src_path = PROJECT_ROOT / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: E:\Projetos\prompt2promolab

# %%
from pathlib import Path

for p in sorted(PROJECT_ROOT.rglob("*")):
    if ".git" in p.parts or "__pycache__" in p.parts:
        continue
    if p.is_file():
        print(p.relative_to(PROJECT_ROOT))
# Out:
# .gitattributes
# .gitignore
# docs\research_notes.md
# LICENSE
# notebooks\00_repo_overview.ipynb
# notebooks\01_model_selector_and_smoke_test.ipynb
# notebooks\02_generate_reel_15s.ipynb
# notebooks\03_generate_reel_30s.ipynb
# notebooks\04_generate_reel_45s.ipynb
# notebooks\05_generate_institutional_long_video.ipynb
# notebooks\06_prompt_lab_nazaapp.ipynb
# prompts\brands\nazaapp_brand_pack.yaml
# prompts\brands\nazaapp_examples.md
# prompts\templates\institutional_template.md
# prompts\templates\reel_15s_template.md
# prompts\templates\reel_30s_template.md
# prompts\templates\reel_45s_template.md
# pyproject.toml
# README.md
# requirements.txt
# scripts\concat_storyboard.py
# src\prompt2promolab\__init__.py
# src\prompt2promolab\config.py
# src\prompt2promolab\ffmpeg_utils.py
# src\prompt2promolab\pipelines.py
# src\prompt2promolab\prompting.py
# src\prompt2promolab\render.py
# src\prompt2promolab\storyboard.py
# storyboards\nazaapp_15s.json
# storyboards\nazaapp_30s.json
# storyboards\nazaapp_45s.json
# storyboards\nazaapp_institutional.json

# %% [markdown]
# ## Fluxo recomendado
#
# 1. escolha um perfil de modelo
# 2. abra um storyboard pronto
# 3. gere clips curtos por cena
# 4. concatene em um vídeo final
# 5. teste variações de hook, benefício e CTA

# %%
import json

storyboard_path = PROJECT_ROOT / "storyboards" / "nazaapp_15s.json"
data = json.loads(storyboard_path.read_text(encoding="utf-8"))
data
# Out:
# {'slug': 'nazaapp_15s',
#  'title': 'NazaApp — Reel 15s',
#  'clip_seconds': 5,
#  'scenes': [{'scene_id': 1,
#    'seconds': 5,
#    'prompt': 'A church secretary overwhelmed with paper notes, spreadsheets and phone messages, realistic office scene inside a church administration room, subtle handheld camera, natural morning light, modern promotional style, feeling of disorganization before digital transformation',
#    'negative_prompt': 'blurry, low quality, extra fingers, deformed face, duplicated body, bad anatomy, warped text, unreadable UI, flicker, jitter, distorted phone screen',
#    'overlay_text': 'Sua igreja ainda organiza tudo no improviso?'},
#   {'scene_id': 2,
#    'seconds': 5,
#    'prompt': 'A clean laptop dashboard and smartphone showing a church management app in use, secretary smiling while organizing members, events and communication, smooth gimbal camera, bright and tidy church office, warm trustworthy light, realistic SaaS promo look',
#    'negative_prompt': 'blurry, low quality, extra fingers, deformed face, duplicated body, bad anatomy, warped text, unreadable UI, flicker, jitter, distorted phone screen',
#    'overlay_text': 'Centralize membros, agenda e comunicação'},
#   {'scene_id': 3,
#    'seconds': 5,
#    'prompt': 'Pastor and church team checking notifications and schedule on phone and computer, modern church lobby, gentle push-in camera movement, sunset warm light, uplifting and hopeful mood, final promotional shot ready for call to action',
#    'negative_prompt': 'blurry, low quality, extra fingers, deformed face, duplicated body, bad anatomy, warped text, unreadable UI, flicker, jitter, distorted phone screen',
#    'overlay_text': 'Conheça a NazaApp'}]}
