# %% [markdown]
# # 01 — Model selector and smoke test

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

src_path = PROJECT_ROOT / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: E:\Projetos\prompt2promolab

# %%
from prompt2promolab.config import MODEL_REGISTRY

for key, profile in MODEL_REGISTRY.items():
    print("=" * 80)
    print("key:", key)
    print("name:", profile.display_name)
    print("repo:", profile.hf_repo)
    print("notes:", profile.notes)
# Out:
# ================================================================================
# key: small_gpu
# name: CogVideoX-2B (small / lower cost)
# repo: zai-org/CogVideoX-2b
# notes: Best entry point for smaller GPUs. Try quantization and CPU offload if memory is tight.
# ================================================================================
# key: balanced
# name: LTX-Video (balanced / faster iteration)
# repo: Lightricks/LTX-Video
# notes: Good balance between speed and quality for repeated ad testing.
# ================================================================================
# key: quality_14gb_plus
# name: HunyuanVideo-1.5 (higher quality)
# repo: Tencent-Hunyuan/HunyuanVideo-1.5
# notes: Use when you have more VRAM and want better institutional pieces.

# %% [markdown]
# Escolha o perfil mais adequado:
#
# - `small_gpu`: começar em hardware menor
# - `balanced`: mais velocidade para experimentos
# - `quality_14gb_plus`: melhor qualidade com GPU mais forte

# %%
PROFILE_KEY = "small_gpu"  # altere aqui
SMOKE_TEST_ONLY = False    # mude para True para só validar import/configuração

# %%
from prompt2promolab.pipelines import load_pipeline

if SMOKE_TEST_ONLY:
    print("Smoke test configurado. Nenhum modelo será carregado.")
else:
    pipe = load_pipeline(PROFILE_KEY)
    print("Pipeline carregado com sucesso:", type(pipe))
# Out:
# model_index.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# c:\Users\nielsen.castelo\AppData\Local\anaconda3\envs\GPU_Torch\lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nielsen.castelo\.cache\huggingface\hub\models--zai-org--CogVideoX-2b. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
