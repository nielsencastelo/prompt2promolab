# %% [markdown]
# # 06 — Prompt lab NazaApp

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

src_path = PROJECT_ROOT / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print("PROJECT_ROOT:", PROJECT_ROOT)

# %%
import yaml
from pathlib import Path

brand = yaml.safe_load((PROJECT_ROOT / "prompts" / "brands" / "nazaapp_brand_pack.yaml").read_text(encoding="utf-8"))
brand

# %%
from prompt2promolab.prompting import build_marketing_prompt, default_negative_prompt

prompt = build_marketing_prompt(
    subject="A church secretary using NazaApp on laptop and smartphone",
    action="organizing members, events and communication with confidence",
    environment="inside a clean and modern church office",
    camera="smooth cinematic push-in shot",
    lighting="warm natural light and clear professional commercial look",
    mood="hopeful, organized, trustworthy",
    brand_hint="promotional video for church management software",
)

negative = default_negative_prompt()
print("PROMPT:\n", prompt)
print("\nNEGATIVE:\n", negative)

# %% [markdown]
# ## Ideias de testes
#
# 1. variar o opening hook
# 2. variar o público (`pastor`, `secretaria`, `líder de ministério`)
# 3. variar o CTA
# 4. manter mesma cena e trocar apenas iluminação ou câmera

# %%
variants = [
    {
        "name": "hook_secretaria",
        "prompt": build_marketing_prompt(
            subject="A church secretary with paper notes and messages everywhere",
            action="trying to organize church activities before using NazaApp",
            environment="small church office",
            camera="realistic handheld documentary shot",
            lighting="natural morning light",
            mood="stress turning into relief",
            brand_hint="before and after promotional video",
        ),
    },
    {
        "name": "hook_pastor",
        "prompt": build_marketing_prompt(
            subject="A pastor reviewing a dashboard and mobile app with confidence",
            action="checking events, communication and member information",
            environment="welcoming church lobby",
            camera="smooth gimbal movement",
            lighting="warm sunset light",
            mood="calm leadership and trust",
            brand_hint="church software promotional piece",
        ),
    },
]

variants
